# %%
import pandas as pd
data = pd.read_csv("output\SN2007af_magarray.csv", sep=",")

# %%
data = pd.read_csv("output\SN2007af_magarray.csv", sep=",")
time=list(data['Time (MJD)'])

# %%
data=data.set_index('Time (MJD)')
data.dropna(axis=0, how='all')
# Out:
#               UVW2  Error1    UVM2  Error2    UVW1  Error3       U  Error4  \
# Time (MJD)
# 54161.8408     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 54165.0591  18.788   0.189     NaN     NaN     NaN     NaN     NaN     NaN
# 54169.6568     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 54170.6312     NaN     NaN  19.673     NaN     NaN     NaN     NaN     NaN
# 54171.5313     NaN     NaN     NaN     NaN  17.243   0.088     NaN     NaN
# 54172.3682     NaN     NaN     NaN     NaN     NaN     NaN  15.380   0.057
# 54173.0383     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 54175.6145     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 54176.5487     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 54177.5535  18.815   0.195     NaN     NaN     NaN     NaN     NaN     NaN
# 54178.5577     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
data_1=data['UVW2']
data_1=data_1.dropna()
time=list(data_1.index.values)
data_1
# Out:
# Time (MJD)
# 54165.0591    18.788
# 54177.5535    18.815
# 54200.1088    17.499
# 54213.7318    17.358
# Name: UVW2, dtype: float64

# %%
data_2=data['UVM2']
data_2=data_2.dropna()
time=list(data_2.index.values)
data_2
# Out:
# Time (MJD)
# 54170.6312    19.673
# 54179.5612    19.636
# 54204.4517    18.966
# 54217.2887    19.253
# Name: UVM2, dtype: float64

# %%
data_3=data['UVW1']
data_3=data_3.dropna()
time=list(data_3.index.values)
data_3
# Out:
# Time (MJD)
# 54171.5313    17.243
# 54206.5268    15.638
# Name: UVW1, dtype: float64

# %%
data_4=data['U']
data_4=data_4.dropna()
time=list(data_4.index.values)
data_4
# Out:
# Time (MJD)
# 54172.3682    15.380
# 54208.7714    13.885
# 54237.9345    14.670
# 54272.4349    14.432
# Name: U, dtype: float64

# %%
data_5=data['B']
data_5=data_5.dropna()
time=list(data_5.index.values)
data_5
# Out:
# Time (MJD)
# 54161.8408    15.085
# 54175.6145    14.948
# 54176.5487    15.106
# 54183.2301    14.935
# 54195.8152    14.039
# 54196.2686    14.148
# 54211.7969    14.103
# 54219.8194    14.071
# 54240.9563    13.889
# Name: B, dtype: float64

# %%
data_6=data['V']
data_6=data_6.dropna()
time=list(data_6.index.values)
data_6
# Out:
# Time (MJD)
# 54169.6568    15.042
# 54173.0383    14.830
# 54178.5577    14.995
# 54186.2459    14.787
# 54187.2817    14.488
# 54188.2833    14.466
# 54189.4245    14.234
# 54193.0203    14.009
# 54202.4308    14.140
# 54215.3133    14.101
# 54223.4978    14.034
# 54244.4183    13.856
# Name: V, dtype: float64

# %%
data_7=data['R']
data_7=data_7.dropna()
time=list(data_7.index.values)
data_7
# Out:
# Time (MJD)
# 54185.3758    14.609
# 54231.4648    13.969
# 54268.5886    13.800
# Name: R, dtype: float64

# %%
data_8=data['I']
data_8=data_8.dropna()
time=list(data_8.index.values)
data_8
# Out:
# Time (MJD)
# 54184.4750    14.590
# 54227.7947    14.233
# 54258.2466    14.049
# Name: I, dtype: float64

# %%
x=3*4
x
# Out:
# 12

# %%
x=[1,2,3]
y=[1,2,3]
x[1]+=y[1]
x
# Out:
# [1, 4, 3]
